# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# Graph
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Wrappers
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Prediction
pred = pred = conv_net(x, weights, biases, keep_prob)

# Define loss & optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evalute
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Loop
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run op
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        
        if step % display_step == 0:
            # Calculate batch loss & accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x, y: batch_y, keep_prob: 1.})
            
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        step +=1
    print "Optimization Finished!"
    
    print "Testing Accuracy: ", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.})
# Out:
# Iter 1280, Minibatch Loss= 24606.257812, Training Accuracy= 0.21875
# Iter 2560, Minibatch Loss= 11766.205078, Training Accuracy= 0.45312
# Iter 3840, Minibatch Loss= 8155.550781, Training Accuracy= 0.58594
# Iter 5120, Minibatch Loss= 3539.419922, Training Accuracy= 0.70312
# Iter 6400, Minibatch Loss= 3814.073730, Training Accuracy= 0.75781
# Iter 7680, Minibatch Loss= 7693.272461, Training Accuracy= 0.67188
# Iter 8960, Minibatch Loss= 3064.808105, Training Accuracy= 0.80469
# Iter 10240, Minibatch Loss= 2575.334473, Training Accuracy= 0.81250
# Iter 11520, Minibatch Loss= 1153.081299, Training Accuracy= 0.91406
# Iter 12800, Minibatch Loss= 3430.092773, Training Accuracy= 0.76562
# Iter 14080, Minibatch Loss= 1080.861328, Training Accuracy= 0.89062
# Iter 15360, Minibatch Loss= 1706.800659, Training Accuracy= 0.88281
# Iter 16640, Minibatch Loss= 2097.708252, Training Accuracy= 0.88281
# Iter 17920, Minibatch Loss= 1505.787354, Training Accuracy= 0.89844
# Iter 19200, Minibatch Loss= 318.345947, Training Accuracy= 0.95312
# Iter 20480, Minibatch Loss= 374.423279, Training Accuracy= 0.92969
# Iter 21760, Minibatch Loss= 2246.854492, Training Accuracy= 0.85156
# Iter 23040, Minibatch Loss= 845.619019, Training Accuracy= 0.94531
# Iter 24320, Minibatch Loss= 1301.797607, Training Accuracy= 0.89844
# Iter 25600, Minibatch Loss= 1118.297607, Training Accuracy= 0.91406
# Iter 26880, Minibatch Loss= 743.650146, Training Accuracy= 0.92969
# Iter 28160, Minibatch Loss= 970.072693, Training Accuracy= 0.91406
# Iter 29440, Minibatch Loss= 1605.882568, Training Accuracy= 0.90625
# Iter 30720, Minibatch Loss= 1517.606934, Training Accuracy= 0.86719
# Iter 32000, Minibatch Loss= 451.157074, Training Accuracy= 0.95312
# Iter 33280, Minibatch Loss= 790.729126, Training Accuracy= 0.93750
# Iter 34560, Minibatch Loss= 476.413330, Training Accuracy= 0.95312
# Iter 35840, Minibatch Loss= 410.708496, Training Accuracy= 0.96094
# Iter 37120, Minibatch Loss= 1440.091553, Training Accuracy= 0.87500
# Iter 38400, Minibatch Loss= 31.537079, Training Accuracy= 0.99219
# Iter 39680, Minibatch Loss= 89.039429, Training Accuracy= 0.99219
# Iter 40960, Minibatch Loss= 1234.261963, Training Accuracy= 0.90625
# Iter 42240, Minibatch Loss= 909.796143, Training Accuracy= 0.93750
# Iter 43520, Minibatch Loss= 411.741852, Training Accuracy= 0.96875
# Iter 44800, Minibatch Loss= 233.560379, Training Accuracy= 0.96094
# Iter 46080, Minibatch Loss= 32.021164, Training Accuracy= 0.99219
# Iter 47360, Minibatch Loss= 975.344849, Training Accuracy= 0.94531
# Iter 48640, Minibatch Loss= 990.646484, Training Accuracy= 0.92969
# Iter 49920, Minibatch Loss= 502.987854, Training Accuracy= 0.92969
# Iter 51200, Minibatch Loss= 498.704559, Training Accuracy= 0.94531
# Iter 52480, Minibatch Loss= 613.236450, Training Accuracy= 0.95312
# Iter 53760, Minibatch Loss= 158.651276, Training Accuracy= 0.97656
# Iter 55040, Minibatch Loss= 545.897339, Training Accuracy= 0.94531
# Iter 56320, Minibatch Loss= 642.509644, Training Accuracy= 0.95312
# Iter 57600, Minibatch Loss= 503.045593, Training Accuracy= 0.96094
# Iter 58880, Minibatch Loss= 599.012024, Training Accuracy= 0.94531
# Iter 60160, Minibatch Loss= 442.802124, Training Accuracy= 0.96875
# Iter 61440, Minibatch Loss= 561.020569, Training Accuracy= 0.92188
# Iter 62720, Minibatch Loss= 256.019867, Training Accuracy= 0.96875
# Iter 64000, Minibatch Loss= 564.794983, Training Accuracy= 0.93750
# Iter 65280, Minibatch Loss= 414.479462, Training Accuracy= 0.95312
# Iter 66560, Minibatch Loss= 223.056686, Training Accuracy= 0.97656
# Iter 67840, Minibatch Loss= 205.128708, Training Accuracy= 0.96875
# Iter 69120, Minibatch Loss= 1110.634277, Training Accuracy= 0.92188
# Iter 70400, Minibatch Loss= 185.016434, Training Accuracy= 0.97656
# Iter 71680, Minibatch Loss= 227.533463, Training Accuracy= 0.98438
# Iter 72960, Minibatch Loss= 1037.506104, Training Accuracy= 0.92969
# Iter 74240, Minibatch Loss= 676.270142, Training Accuracy= 0.92969
# Iter 75520, Minibatch Loss= 567.237183, Training Accuracy= 0.94531
# Iter 76800, Minibatch Loss= 548.902222, Training Accuracy= 0.95312
# Iter 78080, Minibatch Loss= 362.474487, Training Accuracy= 0.95312
# Iter 79360, Minibatch Loss= 668.334534, Training Accuracy= 0.92969
# Iter 80640, Minibatch Loss= 431.894287, Training Accuracy= 0.94531
# Iter 81920, Minibatch Loss= 180.932388, Training Accuracy= 0.97656
# Iter 83200, Minibatch Loss= 271.998291, Training Accuracy= 0.97656
# Iter 84480, Minibatch Loss= 47.770325, Training Accuracy= 0.97656
# Iter 85760, Minibatch Loss= 324.731567, Training Accuracy= 0.94531
# Iter 87040, Minibatch Loss= 120.987236, Training Accuracy= 0.97656
# Iter 88320, Minibatch Loss= 406.774811, Training Accuracy= 0.95312
# Iter 89600, Minibatch Loss= 309.076660, Training Accuracy= 0.96094
# Iter 90880, Minibatch Loss= 521.906067, Training Accuracy= 0.93750
# Iter 92160, Minibatch Loss= 497.390625, Training Accuracy= 0.95312
# Iter 93440, Minibatch Loss= 48.059441, Training Accuracy= 0.97656
# Iter 94720, Minibatch Loss= 277.425232, Training Accuracy= 0.96094
# Iter 96000, Minibatch Loss= 400.361328, Training Accuracy= 0.93750
# Iter 97280, Minibatch Loss= 254.438614, Training Accuracy= 0.97656
# Iter 98560, Minibatch Loss= 474.450989, Training Accuracy= 0.95312
# Iter 99840, Minibatch Loss= 255.653625, Training Accuracy= 0.97656
# Iter 101120, Minibatch Loss= 557.168335, Training Accuracy= 0.94531
# Iter 102400, Minibatch Loss= 606.321655, Training Accuracy= 0.92969
# Iter 103680, Minibatch Loss= 333.389679, Training Accuracy= 0.95312
# Iter 104960, Minibatch Loss= 404.662872, Training Accuracy= 0.94531
# Iter 106240, Minibatch Loss= 192.695023, Training Accuracy= 0.95312
# Iter 107520, Minibatch Loss= 287.794556, Training Accuracy= 0.97656
# Iter 108800, Minibatch Loss= 522.102112, Training Accuracy= 0.95312
# Iter 110080, Minibatch Loss= 128.987167, Training Accuracy= 0.97656
# Iter 111360, Minibatch Loss= 75.300926, Training Accuracy= 0.99219
# Iter 112640, Minibatch Loss= 366.943726, Training Accuracy= 0.96094
# Iter 113920, Minibatch Loss= 78.116974, Training Accuracy= 0.98438
# Iter 115200, Minibatch Loss= 281.688965, Training Accuracy= 0.94531
# Iter 116480, Minibatch Loss= 104.924469, Training Accuracy= 0.98438
# Iter 117760, Minibatch Loss= 62.094933, Training Accuracy= 0.98438
# Iter 119040, Minibatch Loss= 4.223618, Training Accuracy= 0.99219
# Iter 120320, Minibatch Loss= 199.225830, Training Accuracy= 0.96875
# Iter 121600, Minibatch Loss= 366.385620, Training Accuracy= 0.96094
# Iter 122880, Minibatch Loss= 247.219177, Training Accuracy= 0.96094
# Iter 124160, Minibatch Loss= 394.171967, Training Accuracy= 0.96094
# Iter 125440, Minibatch Loss= 81.639633, Training Accuracy= 0.96094
# Iter 126720, Minibatch Loss= 80.589645, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 226.301270, Training Accuracy= 0.96875
# Iter 129280, Minibatch Loss= 266.364685, Training Accuracy= 0.97656
# Iter 130560, Minibatch Loss= 585.473389, Training Accuracy= 0.98438
