# %%
import tensorflow as tf
from tensorflow.python.ops import rnn, rnn_cell
import numpy as np

# Import MINST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 100000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 28 # MNIST data input (img shape: 28*28)
n_steps = 28 # timesteps
n_hidden = 128 # hidden layer num of features
n_classes = 10 # MNIST total classes (0-9 digits)


# Graph
x = tf.placeholder("float", [None, n_steps, n_input])
y = tf.placeholder("float", [None, n_classes])

# Define weight and biases
weights = {
    # Hidden layer weights => 2*n_hidden because of foward + backward cells
    'out': tf.Variable(tf.random_normal([2*n_hidden, n_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
def BiRNN(x, weights, biases):

    # Prepare data shape to match `bidirectional_rnn` function requirements
    # Current data input shape: (batch_size, n_steps, n_input)
    # Required shape: 'n_steps' tensors list of shape (batch_size, n_input)
    
    # Permuting batch_size and n_steps
    x = tf.transpose(x, [1, 0, 2])
    # Reshape to (n_steps*batch_size, n_input)
    x = tf.reshape(x, [-1, n_input])
    # Split to get a list of 'n_steps' tensors of shape (batch_size, n_input)
    x = tf.split(0, n_steps, x)

    # Define lstm cells with tensorflow
    # Forward direction cell
    lstm_fw_cell = rnn_cell.BasicLSTMCell(n_hidden, forget_bias=1.0)
    # Backward direction cell
    lstm_bw_cell = rnn_cell.BasicLSTMCell(n_hidden, forget_bias=1.0)

    # Get lstm cell output
    try:
        outputs, _, _ = rnn.bidirectional_rnn(lstm_fw_cell, lstm_bw_cell, x,
                                              dtype=tf.float32)
    except Exception: # Old TensorFlow version only returns outputs not states
        outputs = rnn.bidirectional_rnn(lstm_fw_cell, lstm_bw_cell, x,
                                        dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

# Prediction
pred = BiRNN(x, weights, biases)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Reshape data to get 28 seq of 28 elements
        batch_x = batch_x.reshape((batch_size, n_steps, n_input))
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        if step % display_step == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, feed_dict={x: batch_x, y: batch_y})
            # Calculate batch loss
            loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 128 mnist test images
    test_len = 128
    test_data = mnist.test.images[:test_len].reshape((-1, n_steps, n_input))
    test_label = mnist.test.labels[:test_len]
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: test_data, y: test_label})
# Out:
# Iter 1280, Minibatch Loss= 1.652585, Training Accuracy= 0.46875
# Iter 2560, Minibatch Loss= 1.385769, Training Accuracy= 0.55469
# Iter 3840, Minibatch Loss= 1.096227, Training Accuracy= 0.62500
# Iter 5120, Minibatch Loss= 0.843821, Training Accuracy= 0.71875
# Iter 6400, Minibatch Loss= 0.694401, Training Accuracy= 0.77344
# Iter 7680, Minibatch Loss= 0.963876, Training Accuracy= 0.67188
# Iter 8960, Minibatch Loss= 0.601108, Training Accuracy= 0.79688
# Iter 10240, Minibatch Loss= 0.521250, Training Accuracy= 0.80469
# Iter 11520, Minibatch Loss= 0.338575, Training Accuracy= 0.90625
# Iter 12800, Minibatch Loss= 0.521441, Training Accuracy= 0.80469
# Iter 14080, Minibatch Loss= 0.392410, Training Accuracy= 0.89062
# Iter 15360, Minibatch Loss= 0.288913, Training Accuracy= 0.94531
# Iter 16640, Minibatch Loss= 0.376650, Training Accuracy= 0.92188
# Iter 17920, Minibatch Loss= 0.249301, Training Accuracy= 0.92969
# Iter 19200, Minibatch Loss= 0.234679, Training Accuracy= 0.92188
# Iter 20480, Minibatch Loss= 0.101816, Training Accuracy= 0.97656
# Iter 21760, Minibatch Loss= 0.409535, Training Accuracy= 0.83594
# Iter 23040, Minibatch Loss= 0.164328, Training Accuracy= 0.93750
# Iter 24320, Minibatch Loss= 0.334861, Training Accuracy= 0.86719
# Iter 25600, Minibatch Loss= 0.346976, Training Accuracy= 0.89844
# Iter 26880, Minibatch Loss= 0.165843, Training Accuracy= 0.93750
# Iter 28160, Minibatch Loss= 0.239312, Training Accuracy= 0.92188
# Iter 29440, Minibatch Loss= 0.282129, Training Accuracy= 0.91406
# Iter 30720, Minibatch Loss= 0.287742, Training Accuracy= 0.91406
# Iter 32000, Minibatch Loss= 0.171226, Training Accuracy= 0.92969
# Iter 33280, Minibatch Loss= 0.219461, Training Accuracy= 0.92969
# Iter 34560, Minibatch Loss= 0.246006, Training Accuracy= 0.94531
# Iter 35840, Minibatch Loss= 0.168688, Training Accuracy= 0.95312
# Iter 37120, Minibatch Loss= 0.245120, Training Accuracy= 0.93750
# Iter 38400, Minibatch Loss= 0.176031, Training Accuracy= 0.93750
# Iter 39680, Minibatch Loss= 0.096283, Training Accuracy= 0.96875
# Iter 40960, Minibatch Loss= 0.254728, Training Accuracy= 0.88281
# Iter 42240, Minibatch Loss= 0.136431, Training Accuracy= 0.96094
# Iter 43520, Minibatch Loss= 0.192867, Training Accuracy= 0.94531
# Iter 44800, Minibatch Loss= 0.166644, Training Accuracy= 0.94531
# Iter 46080, Minibatch Loss= 0.098576, Training Accuracy= 0.96094
# Iter 47360, Minibatch Loss= 0.207252, Training Accuracy= 0.94531
# Iter 48640, Minibatch Loss= 0.242150, Training Accuracy= 0.92969
# Iter 49920, Minibatch Loss= 0.247303, Training Accuracy= 0.90625
# Iter 51200, Minibatch Loss= 0.081365, Training Accuracy= 0.96875
# Iter 52480, Minibatch Loss= 0.109436, Training Accuracy= 0.96875
# Iter 53760, Minibatch Loss= 0.045934, Training Accuracy= 0.99219
# Iter 55040, Minibatch Loss= 0.161633, Training Accuracy= 0.92969
# Iter 56320, Minibatch Loss= 0.101137, Training Accuracy= 0.96094
# Iter 57600, Minibatch Loss= 0.179632, Training Accuracy= 0.93750
# Iter 58880, Minibatch Loss= 0.153902, Training Accuracy= 0.93750
# Iter 60160, Minibatch Loss= 0.197317, Training Accuracy= 0.92969
# Iter 61440, Minibatch Loss= 0.121725, Training Accuracy= 0.95312
# Iter 62720, Minibatch Loss= 0.089139, Training Accuracy= 0.96875
# Iter 64000, Minibatch Loss= 0.118740, Training Accuracy= 0.96875
# Iter 65280, Minibatch Loss= 0.167901, Training Accuracy= 0.96094
# Iter 66560, Minibatch Loss= 0.114734, Training Accuracy= 0.95312
# Iter 67840, Minibatch Loss= 0.061098, Training Accuracy= 0.99219
# Iter 69120, Minibatch Loss= 0.083316, Training Accuracy= 0.98438
# Iter 70400, Minibatch Loss= 0.083833, Training Accuracy= 0.96875
# Iter 71680, Minibatch Loss= 0.055001, Training Accuracy= 0.99219
# Iter 72960, Minibatch Loss= 0.087057, Training Accuracy= 0.97656
# Iter 74240, Minibatch Loss= 0.119025, Training Accuracy= 0.96094
# Iter 75520, Minibatch Loss= 0.075583, Training Accuracy= 0.96875
# Iter 76800, Minibatch Loss= 0.077720, Training Accuracy= 0.97656
# Iter 78080, Minibatch Loss= 0.121395, Training Accuracy= 0.94531
# Iter 79360, Minibatch Loss= 0.097297, Training Accuracy= 0.97656
# Iter 80640, Minibatch Loss= 0.120999, Training Accuracy= 0.95312
# Iter 81920, Minibatch Loss= 0.103817, Training Accuracy= 0.96875
# Iter 83200, Minibatch Loss= 0.090900, Training Accuracy= 0.96094
# Iter 84480, Minibatch Loss= 0.029407, Training Accuracy= 0.99219
# Iter 85760, Minibatch Loss= 0.183641, Training Accuracy= 0.95312
# Iter 87040, Minibatch Loss= 0.037360, Training Accuracy= 0.99219
# Iter 88320, Minibatch Loss= 0.075554, Training Accuracy= 0.98438
# Iter 89600, Minibatch Loss= 0.131984, Training Accuracy= 0.95312
# Iter 90880, Minibatch Loss= 0.043591, Training Accuracy= 0.99219
# Iter 92160, Minibatch Loss= 0.076620, Training Accuracy= 0.97656
# Iter 93440, Minibatch Loss= 0.102335, Training Accuracy= 0.96875
# Iter 94720, Minibatch Loss= 0.142229, Training Accuracy= 0.95312
# Iter 96000, Minibatch Loss= 0.057651, Training Accuracy= 0.98438
# Iter 97280, Minibatch Loss= 0.034084, Training Accuracy= 0.98438
# Iter 98560, Minibatch Loss= 0.125318, Training Accuracy= 0.96094
# Iter 99840, Minibatch Loss= 0.109202, Training Accuracy= 0.95312
# Optimization Finished!
# Testing Accuracy: 0.992188
